# %% [markdown]
# <a href="https://colab.research.google.com/github/MeRitisha/EXCELR-assignments/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset=pd.read_csv('hate_speech.csv')
dataset.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
dataset.shape
# Out:
# (5242, 3)

# %%
dataset.label.value_counts()
# Out:
# label
# 0    3000
# 1    2242
# Name: count, dtype: int64

# %%
for index,tweet in enumerate(dataset["tweet"][10:15]):
    print(index+1,"-",tweet)
# Out:
# 1 -  â #ireland consumer price index (mom) climbed from previous 0.2% to 0.5% in may   #blog #silver #gold #forex
# 2 - we are so selfish. #orlando #standwithorlando #pulseshooting #orlandoshooting #biggerproblems #selfish #heabreaking   #values #love #
# 3 - i get to see my daddy today!!   #80days #gettingfed
# 4 - ouch...junior is angryð#got7 #junior #yugyoem   #omg
# 5 - i am thankful for having a paner. #thankful #positive

# %%
import re
def clean_text(text):
    text=re.sub(r'[^a-zA-Z\']',' ',text)
    text=re.sub(r'[^\x00-\x7f]+','',text)
    text=text.lower()
    return text

# %%
dataset['clean_text'] = dataset.tweet.apply(lambda x:clean_text(x))
dataset.head(10)
# Out:
#    id  ...                                         clean_text
# 0   1  ...    user when a father is dysfunctional and is s...
# 1   2  ...   user  user thanks for  lyft credit i can't us...
# 2   3  ...                                bihday your majesty
# 3   4  ...   model   i love u take with u all the time in ...
# 4   5  ...             factsguide  society now     motivation
# 5   6  ...        huge fan fare and big talking before the...
# 6   7  ...    user camping tomorrow  user  user  user  use...
# 7   8  ...  the next school year is the year for exams    ...
# 8   9  ...  we won    love the land     allin  cavs  champ...
# 9  10  ...    user  user welcome here    i'm   it's so  gr...
#
# [10 rows x 4 columns]

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
len(stopwords.words('english'))
stop=stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from nltk.corpus import stopwords
len(stopwords.words('english'))
stop=stopwords.words('english')

# %%
def gen_freq(text):
    word_list=[]
    for tw_words in text.split():
        word_list.extend(tw_words)
    word_freq=pd.Series(word_list).value_counts()
    word_freq=word_freq.drop(stop,errors='ignore')
    return word_freq

# %%
def any_neg(words):
    for word in words:
        if word in ['n','no','non','not'] or re.search(r"\wn't",word):
            return 1
        else:
            return 0

# %%
dataset.head(10)
# Out:
#    id  ...                                         clean_text
# 0   1  ...    user when a father is dysfunctional and is s...
# 1   2  ...   user  user thanks for  lyft credit i can't us...
# 2   3  ...                                bihday your majesty
# 3   4  ...   model   i love u take with u all the time in ...
# 4   5  ...             factsguide  society now     motivation
# 5   6  ...        huge fan fare and big talking before the...
# 6   7  ...    user camping tomorrow  user  user  user  use...
# 7   8  ...  the next school year is the year for exams    ...
# 8   9  ...  we won    love the land     allin  cavs  champ...
# 9  10  ...    user  user welcome here    i'm   it's so  gr...
#
# [10 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
X = dataset[['word_count','any_neg','any_rare','char_count','is_question']]
y = dataset.label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-af38657d8f11> in <cell line: 0>()
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X = dataset[['word_count','any_neg','any_rare','char_count','is_question']]
#       3 y = dataset.label
#       4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

nltk.download('stopwords')
stop = stopwords.words('english')

# Assuming 'dataset' is your DataFrame loaded from 'hate_speech.csv'

# Function to clean the text
def clean_text(text):
    text = re.sub(r'[^a-zA-Z\']', ' ', text)
    text = re.sub(r'[^\x00-\x7f]+', '', text)
    text = text.lower()
    return text

dataset['clean_text'] = dataset.tweet.apply(lambda x: clean_text(x))

# Function to calculate word frequencies
def gen_freq(text):
    word_list = []
    for tw_words in text.split():
        word_list.extend(tw_words)
    word_freq = pd.Series(word_list).value_counts()
    word_freq = word_freq.drop(stop, errors='ignore')
    return word_freq

# Function to check for negative words
def any_neg(words):
    for word in words:
        if word in ['n', 'no', 'non', 'not'] or re.search(r"\wn't", word):
            return 1
        else:
            return 0

# Function to count rare words
def any_rare(words, rare_words):
    count = 0
    for word in words:
        if word in rare_words:
            count += 1
    return count

# Create features
dataset['word_count'] = dataset['clean_text'].apply(lambda x: len(str(x).split(" ")))
dataset['char_count'] = dataset['clean_text'].str.len()  # includes spaces
dataset['is_question'] = dataset['clean_text'].apply(lambda x: 1 if '?' in x else 0)
dataset['any_neg'] = dataset['clean_text'].apply(lambda x: any_neg(x.split()))

# Creating a list of rare words in the dataset
# Replace threshold (here 5) based on your definition of rare word

word_freq = gen_freq(dataset['clean_text'].str.cat(sep=' '))
rare_words = word_freq[word_freq < 5].index.tolist()
dataset['any_rare'] = dataset['clean_text'].apply(lambda x: any_rare(x.split(), rare_words))


# Splitting the data
X = dataset[['word_count', 'any_neg', 'any_rare', 'char_count', 'is_question']]
y = dataset.label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Model Training and prediction
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

nltk.download('stopwords')
stop = stopwords.words('english')

# Assuming 'dataset' is your DataFrame loaded from 'hate_speech.csv'

# Function to clean the text
def clean_text(text):
    text = re.sub(r'[^a-zA-Z\']', ' ', text)
    text = re.sub(r'[^\x00-\x7f]+', '', text)
    text = text.lower()
    return text

dataset['clean_text'] = dataset.tweet.apply(lambda x: clean_text(x))

# Function to calculate word frequencies
def gen_freq(text):
    word_list = []
    for tw_words in text.split():
        word_list.extend(tw_words)
    word_freq = pd.Series(word_list).value_counts()
    word_freq = word_freq.drop(stop, errors='ignore')
    return word_freq

# Function to check for negative words
def any_neg(words):
    for word in words:
        if word in ['n', 'no', 'non', 'not'] or re.search(r"\wn't", word):
            return 1
        else:
            return 0

# Function to count rare words
def any_rare(words, rare_words):
    count = 0
    for word in words:
        if word in rare_words:
            count += 1
    return count

# Create features
dataset['word_count'] = dataset['clean_text'].apply(lambda x: len(str(x).split(" ")))
dataset['char_count'] = dataset['clean_text'].str.len()  # includes spaces
dataset['is_question'] = dataset['clean_text'].apply(lambda x: 1 if '?' in x else 0)
dataset['any_neg'] = dataset['clean_text'].apply(lambda x: any_neg(x.split()))

# Creating a list of rare words in the dataset
# Replace threshold (here 5) based on your definition of rare word

word_freq = gen_freq(dataset['clean_text'].str.cat(sep=' '))
rare_words = word_freq[word_freq < 5].index.tolist()
dataset['any_rare'] = dataset['clean_text'].apply(lambda x: any_rare(x.split(), rare_words))


# Splitting the data
X = dataset[['word_count', 'any_neg', 'any_rare', 'char_count', 'is_question']]
y = dataset.label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Model Training and prediction
# Using GaussianNB
model = GaussianNB()
model = model.fit(X_train, y_train)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model = model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
model.predict(x_test[5:10])
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,pred)*100,"%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-303028b4afda> in <cell line: 0>()
# ----> 1 model.predict(x_test[5:10])
#       2 from sklearn.metrics import accuracy_score
#       3 print(accuracy_score(y_test,pred)*100,"%")
#
# NameError: name 'x_test' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier
clf_rf = RandomForestClassifier
clf_rl.fit(X_train, y_train)
clf_rl.fit(X_test, y_test)
rl_pred = model.predict(X_test).astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-fac29d117444> in <cell line: 0>()
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 clf_rf = RandomForestClassifier
# ----> 3 clf_rl.fit(X_train, y_train)
#       4 clf_rl.fit(X_test, y_test)
#       5 rl_pred = model.predict(X_test).astype(int)
#
# NameError: name 'clf_rl' is not defined

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test,rf_pred))
print(classification_report(y_test,rf_pred))
print(accuracy_score(y_test,rf_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-b074777f967c> in <cell line: 0>()
#       1 from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
# ----> 2 print(confusion_matrix(y_test,rf_pred))
#       3 print(classification_report(y_test,rf_pred))
#       4 print(accuracy_score(y_test,rf_pred))
#
# NameError: name 'rf_pred' is not defined
